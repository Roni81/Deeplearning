# %% [markdown]
# <a href="https://colab.research.google.com/github/Roni81/Deeplearning/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#custom dataset  -> pretrainde model(Yolo) + fine tunning

# %%
# !wget -O Aquarium_Data.zip https://public.roboflow.com/ds/8Xvc7WqcXW?key=Nvc9kwGlbC
# Out:
# --2023-11-21 08:32:35--  https://public.roboflow.com/ds/8Xvc7WqcXW?key=Nvc9kwGlbC
# Resolving public.roboflow.com (public.roboflow.com)... 151.101.1.195, 151.101.65.195
# Connecting to public.roboflow.com (public.roboflow.com)|151.101.1.195|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com/roboflow-platform-exports/5w20VzQObTXjJhTjq6kad9ubrm33/SjsZRQlmDqyawO3e26tc/2/yolov8.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=481589474394-compute%40developer.gserviceaccount.com%2F20231121%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20231121T083235Z&X-Goog-Expires=901&X-Goog-SignedHeaders=host&X-Goog-Signature=... [following]
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import zipfile

# %%
with zipfile.ZipFile('/content/Aquarium_Data.zip') as target_file:
  target_file.extractall('/content/Aquarium_Data')

# %%
# !pip install PyYAML

# %%
import yaml

# %%
data = {
    'train': '/content/drive/MyDrive/BTS/train/images',
    'test': '/content/drive/MyDrive/BTS/test/images',
    'val' : '/content/drive/MyDrive/BTS/vaild/images',
    'names': ['Sugar', 'V', 'Jimin',
              'Jin', 'Jungook', 'J_hope'
              , 'RM'],
    'nc':7
}

# %%
with open("/content/drive/MyDrive/BTS/BTS.yaml", "w") as f:
  yaml.dump(data,f)

# %%
with open("/content/drive/MyDrive/BTS/BTS.yaml", "r") as f:
  aquarium_yaml = yaml.safe_load(f)
  display(aquarium_yaml)
# Out:
# {'names': ['Sugar', 'V', 'Jimin', 'Jin', 'Jungook', 'J_hope', 'RM'],
#  'nc': 7,
#  'test': '/content/drive/MyDrive/BTS/test/images',
#  'train': '/content/drive/MyDrive/BTS/train/images',
#  'val': '/content/drive/MyDrive/BTS/vaild/images'}

# %%
pip install ultralytics

# %%
import ultralytics

# %%
from ultralytics import YOLO

# %%
#YOLO("사전학습된모델명")
model=YOLO("yolov8n.pt")

# %%
len(model.names)
model.names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
# ...

# %%
epochs = 100
patience = 5
batch = 32
image_size = 416


model.train(data = '/content/drive/MyDrive/BTS/BTS.yaml',
            epochs = epochs,
            patience = patience,
            batch = batch,
            imgsz = image_size)
#사전 학습된 yolo 모델에 내가 가지고 있는 커스텀 데이터로 추가 학습(파인튜닝)
# Out:
# Ultralytics YOLOv8.0.215 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
len(model.names)
model.names
# Out:
# {0: 'Sugar', 1: 'V', 2: 'Jimin', 3: 'Jin', 4: 'Jungook', 5: 'J_hope', 6: 'RM'}

# %%
from glob import glob

# %%
test_img = glob('/content/drive/MyDrive/BTS/test/images/*')

# %%
len(test_img)
# Out:
# 27

# %%
test_img.sort()

# %%
test_img
results = model.predict(source = '/content/drive/MyDrive/BTS/test/images', save = True)
# Out:
# image 1/27 /content/drive/MyDrive/BTS/test/images/202006051380025363_1.jpg: 416x320 (no detections), 53.0ms
# image 2/27 /content/drive/MyDrive/BTS/test/images/2023040301000082100003071.jpg: 320x416 1 Jimin, 51.2ms
# image 3/27 /content/drive/MyDrive/BTS/test/images/BTS V new pics1695463995381.jpg: 256x416 (no detections), 52.1ms
# image 4/27 /content/drive/MyDrive/BTS/test/images/BTS-RM-New.jpg: 256x416 (no detections), 7.5ms
# image 5/27 /content/drive/MyDrive/BTS/test/images/BTS-RM-SOLO-ALBUM-MAIN-9364c206-05a9-4607-944b-0cd47100ae4f.jpg: 288x416 1 V, 51.6ms
# image 6/27 /content/drive/MyDrive/BTS/test/images/HD-wallpaper-rm-bangtan-sonyeondan-bts-bts-be-bts-fila-bts-life-goes-on-bts-namjoon-bts-rm-kim-namjoon-namjoon-rm-fila.jpg: 416x224 (no detections), 54.6ms
# image 7/27 /content/drive/MyDrive/BTS/test/images/J-Hope_for_Dispatch__Boy_With_Luv__MV_behind_the_scene_shooting,_15_March_2019_05_(cropped).jpg: 416x320 (no detections), 8.5ms
# ...

# %%
results
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Sugar', 1: 'V', 2: 'Jimin', 3: 'Jin', 4: 'Jungook', 5: 'J_hope', 6: 'RM'}
#  orig_img: array([[[254, 235, 230],
#          [254, 235, 230],
#          [254, 235, 230],
#          ...,
#          [253, 233, 228],
#          [253, 233, 228],
#          [253, 233, 228]],
#
#         [[254, 235, 230],
#          [254, 235, 230],
#          [254, 235, 230],
#          ...,
#          [253, 233, 228],
#          [253, 233, 228],
#          [253, 233, 228]],
#
#         [[254, 235, 230],
#          [254, 235, 230],
#          [254, 235, 230],
#          ...,
#          [253, 233, 228],
#          [253, 233, 228],
#          [253, 233, 228]],
#
#         ...,
#
#         [[249, 220, 216],
#          [249, 220, 216],
#          [249, 220, 216],
#          ...,
#          [242, 214, 207],
#          [244, 216, 209],
# ...

# %%
import numpy as np

# %%
for result in results:

    uniq, cnt = np.unique(result.boxes.cls.cpu().numpy(), return_counts=True)  # Torch.Tensor -> numpy
    uniq_cnt_dict = dict(zip(uniq, cnt))

    print('\n{class num:counts} =', uniq_cnt_dict,'\n')

    for c in result.boxes.cls:
        print('class num =', int(c), ', class_name =', model.names[int(c)])
# Out:
# {class num:counts} = {}
#
#
# {class num:counts} = {2.0: 1}
#
# class num = 2 , class_name = Jimin
#
# {class num:counts} = {}
#
#
# {class num:counts} = {}
#
#
# {class num:counts} = {1.0: 1}
#
# class num = 1 , class_name = V
#
# {class num:counts} = {}
#
#
# {class num:counts} = {}
#
#
# {class num:counts} = {1.0: 1}
#
# class num = 1 , class_name = V
#
# {class num:counts} = {}
#
#
# {class num:counts} = {}
#
#
# {class num:counts} = {1.0: 1}
#
# class num = 1 , class_name = V
#
# {class num:counts} = {1.0: 1}
#
# class num = 1 , class_name = V
#
# {class num:counts} = {}
#
#
# {class num:counts} = {2.0: 1}
#
# class num = 2 , class_name = Jimin
#
# {class num:counts} = {}
#
#
# {class num:counts} = {2.0: 1}
#
# class num = 2 , class_name = Jimin
#
# {class num:counts} = {}
#
#
# {class num:counts} = {}
#
#
# {class num:counts} = {}
#
#
# {class num:counts} = {1.0: 1}
#
# class num = 1 , class_name = V
#
# {class num:counts} = {1.0: 1}
#
# class num = 1 , class_name = V
#
# ...
