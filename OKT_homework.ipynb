# %%
pip install google-api-python-client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for google-api-python-client from https://files.pythonhosted.org/packages/95/a3/8a1850351bdb05ee0a5a31931961b26a09ce60c82b2cc9636d9d6ce0fe04/google_api_python_client-2.108.0-py2.py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/96.9 kB ? eta -:--:--
#      ---------------------------------------- 96.9/96.9 kB 5.4 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for google-auth-httplib2>=0.1.0 from https://files.pythonhosted.org/packages/d3/3d/e4991229886c0d522d9552151a43ff7adcc61e026e60ce8bd508387f84cf/google_auth_httplib2-0.1.1-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 from https://files.pythonhosted.org/packages/c4/1e/924dcad4725d2e697888e044edf7a433db84bf9a3e40d3efa38ba859d0ce/google_api_core-2.14.0-py3-none-any.whl.metadata
# ...

# %%
import pandas as pd

from googleapiclient.discovery import build

# %%
AIzaSyCOkvArygGGFBGWGjF5m63ALdITGwWuEa0

# %%
comments = list()
api_obj = build('youtube', 'v3', developerKey='AIzaSyCOkvArygGGFBGWGjF5m63ALdITGwWuEa0')
response = api_obj.commentThreads().list(part='snippet,replies',
                                         videoId='LuxqKFPOM-M',
                                         maxResults=100).execute()

# %%
pd.Dataframe(response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 pd.Dataframe(response)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
response[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 response[0]
#
# KeyError: 0

# %%
list(response)
# Out:
# ['kind', 'etag', 'nextPageToken', 'pageInfo', 'items']

# %%
response['textDisplay']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 response['textDisplay']
#
# KeyError: 'textDisplay'

# %%
response
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'w5hQzmduBSl5oaKbe67l3y0kjhs',
#  'pageInfo': {'totalResults': 18, 'resultsPerPage': 100},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'mJn76XxvUmd0od4Oc-rL2LdFiyM',
#    'id': 'UgxkXRmbpqB3X6jtWit4AaABAg',
#    'snippet': {'channelId': 'UCNhofiqfw5nl-NeDJkXtPvw',
#     'videoId': 'LuxqKFPOM-M',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'IZqwyAkvBMNIX0mMewjLlfsZMBo',
#      'id': 'UgxkXRmbpqB3X6jtWit4AaABAg',
#      'snippet': {'channelId': 'UCNhofiqfw5nl-NeDJkXtPvw',
#       'videoId': 'LuxqKFPOM-M',
#       'textDisplay': '다들 즐길 짐빔 되셨나요???',
#       'textOriginal': '다들 즐길 짐빔 되셨나요???',
#       'authorDisplayName': 'HH G',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKYxLhFZ7vgPvuON9V6qz-C4UupU1BqUecz5XYaS=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCAFMaYE6MCVI4S6xc9gEDbw',
# ...

# %%
while response:
    for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']
        comments.append([comment['textDisplay'], comment['authorDisplayName'], comment['publishedAt'], comment['likeCount']])
 
    if item['snippet']['totalReplyCount'] > 0:
            for reply_item in item['replies']['comments']:
                reply = reply_item['snippet']
                comments.append([reply['textDisplay'], reply['authorDisplayName'], reply['publishedAt'], reply['likeCount']])
 
    if 'nextPageToken' in response:
        response = api_obj.commentThreads().list(part='snippet,replies', videoId='LuxqKFPOM-M', pageToken=response['nextPageToken'], maxResults=100).execute()
    else:
        break

# %%
comment
# Out:
# {'channelId': 'UCNhofiqfw5nl-NeDJkXtPvw',
#  'videoId': 'LuxqKFPOM-M',
#  'textDisplay': 'ㅎㅇ',
#  'textOriginal': 'ㅎㅇ',
#  'authorDisplayName': '누굴까유',
#  'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKaR42Mz5k01sZnKgklE3oozoBZeQScfnk4C-TYRZNxR2A=s48-c-k-c0x00ffffff-no-rj',
#  'authorChannelUrl': 'http://www.youtube.com/channel/UC_ejtwaOneO0CCX2WSWLirg',
#  'authorChannelId': {'value': 'UC_ejtwaOneO0CCX2WSWLirg'},
#  'canRate': True,
#  'viewerRating': 'none',
#  'likeCount': 0,
#  'publishedAt': '2023-09-22T09:00:50Z',
#  'updatedAt': '2023-09-22T09:00:50Z'}

# %%
df = pd.DataFrame(comments)
df.to_excel('results.xlsx', header = ['comment', 'writer', 'date', 'likes'], index = None)

# %%
df
# Out:
#                                                       0                 1  \
# 0     일정 문제로 나중에 여행한 오토바이 여행을 먼저 업로드했습니다.<br>이집트 영상도...  빠니보틀 Pani Bottle
# 1                                                오히려 좋아              TH K
# 2                                         울지마 약소꾸~오빠 달료               sun
# 3                           일단 입막음용 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ목빠짐 방지용 ㅋㅋ            NIJOYH
# 4                                    뭐든 올려주심 감사감사요 ㅎㅎ 😊              영스튜브
# ...                                                 ...               ...
# 1822                                                  1              jh모듈
# 1823                                              와아아아❤   pigpooh pigpooh
# 1824                                              와~~~~               류성민
# 1825                                 퇴근시간에 캬... 잘먹겠습니다.               왕여신
# 1826                                                 ㅎㅇ              누굴까유
#
#                          2     3
# 0     2023-09-22T09:01:38Z  2814
# ...

# %%
df[0][0]
# Out:
# '일정 문제로 나중에 여행한 오토바이 여행을 먼저 업로드했습니다.<br>이집트 영상도 빠른 시일내에 업로드 하겠습니다 ㅜㅜ'

# %%
df = df.dropna(subset = [0])

# %%
df
# Out:
#                                                       0                 1  \
# 0     일정 문제로 나중에 여행한 오토바이 여행을 먼저 업로드했습니다.<br>이집트 영상도...  빠니보틀 Pani Bottle
# 1                                                오히려 좋아              TH K
# 2                                         울지마 약소꾸~오빠 달료               sun
# 3                           일단 입막음용 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ목빠짐 방지용 ㅋㅋ            NIJOYH
# 4                                    뭐든 올려주심 감사감사요 ㅎㅎ 😊              영스튜브
# ...                                                 ...               ...
# 1822                                                  1              jh모듈
# 1823                                              와아아아❤   pigpooh pigpooh
# 1824                                              와~~~~               류성민
# 1825                                 퇴근시간에 캬... 잘먹겠습니다.               왕여신
# 1826                                                 ㅎㅇ              누굴까유
#
#                          2     3
# 0     2023-09-22T09:01:38Z  2814
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1827 entries, 0 to 1826
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1827 non-null   object
#  1   1       1827 non-null   object
#  2   2       1827 non-null   object
#  3   3       1827 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 57.2+ KB

# %%
pip install konlpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/19.4 MB ? eta -:--:--
#      - -------------------------------------- 0.8/19.4 MB 17.4 MB/s eta 0:00:02
#      ---- ----------------------------------- 2.0/19.4 MB 20.9 MB/s eta 0:00:01
#      ------ --------------------------------- 3.3/19.4 MB 23.6 MB/s eta 0:00:01
#      --------- ------------------------------ 4.5/19.4 MB 23.8 MB/s eta 0:00:01
#      ----------- ---------------------------- 5.5/19.4 MB 23.5 MB/s eta 0:00:01
#      ------------- -------------------------- 6.4/19.4 MB 22.8 MB/s eta 0:00:01
#      --------------- ------------------------ 7.6/19.4 MB 23.3 MB/s eta 0:00:01
#      ----------------- ---------------------- 8.7/19.4 MB 23.2 MB/s eta 0:00:01
#      -------------------- ------------------- 9.9/19.4 MB 23.5 MB/s eta 0:00:01
#      ---------------------- ---------------- 11.2/19.4 MB 24.2 MB/s eta 0:00:01
# ...

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from konlpy.tag import Okt
import re

# %%
df[0] = df[0].str.replace(r"[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","", regex = True)

# %%
df
# Out:
#                                                       0                 1  \
# 0     일정 문제로 나중에 여행한 오토바이 여행을 먼저 업로드했습니다이집트 영상도 빠른 시...  빠니보틀 Pani Bottle
# 1                                                오히려 좋아              TH K
# 2                                          울지마 약소꾸오빠 달료               sun
# 3                           일단 입막음용 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ목빠짐 방지용 ㅋㅋ            NIJOYH
# 4                                     뭐든 올려주심 감사감사요 ㅎㅎ               영스튜브
# ...                                                 ...               ...
# 1822                                                                 jh모듈
# 1823                                               와아아아   pigpooh pigpooh
# 1824                                                  와               류성민
# 1825                                     퇴근시간에 캬 잘먹겠습니다               왕여신
# 1826                                                 ㅎㅇ              누굴까유
#
#                          2     3
# 0     2023-09-22T09:01:38Z  2814
# ...

# %%
okt = Okt()
# Out:
# ---------------------------------------------------------------------------
# JVMNotFoundException                      Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 okt = Okt()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\konlpy\tag\_okt.py:51, in Okt.__init__(self, jvmpath, max_heap_size)
#      49 def __init__(self, jvmpath=None, max_heap_size=1024):
#      50     if not jpype.isJVMStarted():
# ---> 51         jvm.init_jvm(jvmpath, max_heap_size)
#      53     oktJavaPackage = jpype.JPackage('kr.lucypark.okt')
#      54     OktInterfaceJavaClass = oktJavaPackage.OktInterface
#
# File ~\AppData\Roaming\Python\Python311\site-packages\konlpy\jvm.py:55, in init_jvm(jvmpath, max_heap_size)
#      52 args = [javadir, os.sep]
#      53 classpath = [f.format(*args) for f in folder_suffix]
# ---> 55 jvmpath = jvmpath or jpype.getDefaultJVMPath()
#      57 # NOTE: Temporary patch for Issue #76. Erase when possible.
#      58 if sys.platform == 'darwin'\
# ...

# %%
export JAVA_HOME="/path/to/your/java/installation"
export PATH=$JAVA_HOME/bin:$PATH
# Out:
#   Cell In[53], line 1
#     export JAVA_HOME="/path/to/your/java/installation"
#            ^
# SyntaxError: invalid syntax

# %%
pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts pip.exe, pip3.11.exe and pip3.exe are installed in 'C:\Users\User\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/47/6a/453160888fab7c6a432a6e25f8afe6256d0d9f2cbd25971021da6491d899/pip-23.3.1-py3-none-any.whl.metadata
#   Using cached pip-23.3.1-py3-none-any.whl.metadata (3.5 kB)
# Using cached pip-23.3.1-py3-none-any.whl (2.1 MB)
# ...

# %%
pip uninstall your_library
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping your_library as it is not installed.

# %%
pip install your_library
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement your_library (from versions: none)
# ERROR: No matching distribution found for your_library

# %%
# Out:
#   Cell In[59], line 1
#     set JAVA_HOME=C:\Path\To\Java
#         ^
# SyntaxError: invalid syntax
